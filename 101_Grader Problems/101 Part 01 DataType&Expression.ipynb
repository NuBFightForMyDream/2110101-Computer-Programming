# %% [markdown]
# # 2110101 Grader Problems
# ## Solution by : Nine #1 General (Gr.E)
# ## Part 01 : Data Type & Expression

# %% [markdown]
# ### Overview
# - 01_01 : Stirling Factorial (1 Star) ☑️🫡
# - 01_02 : Quadratic Root (1 Star) ☑️🫡
# - 01_03 : An Expression (2 Star) ☑️ 🫡
# - 01_04 : Body Surface Area (2 Star) ☑️ 🫡
# - 01_05 : Duration (3 Star) ☑️ 🫡
# ### Function
# - 01_06 : Body Surface Area (Function) (1 Star) ☑️
# - 01_07 : Cube Root (Function) (2 Star) ☑️
# - 01_08 : Duration (Function) (2 Star) ☑️
# ### Special Problems
# - 01_09 : Songkran (1 Star) ☑️
# - 01_10 : Strange Expression (1 Star) ☑️
# - 01_11 : Eyeball (2 Star) ☑️
# - 01_12 : Trigonometry Expression (1 Star) ☑️
# - 01_13 : Projectile Motion (1.5 Star) ☑️

# %% [markdown]
# ### Task 01_01 : Stirling Factorial (1 Star)
# ![Screenshot 2024-08-12 133003.png](attachment:34ac35fa-f339-4c79-83a4-fd9a0e48bf35.png)

# %%
# Logic : รับค่า n! -> เข้าสูตร ขอบบน-ล่าง ! -> print ค่าขอบออกมา
# Step : 
# 1. รับ input n (int)
# 2. กำหนด ตป. n_min , n_max (เข้าสูตร)
# 3. print ขอบบน , ขอบล่าง

# Input : รับ input n (int) + import math
import math # เพื่อใช้ฟังก์ชั่นทางคณิตศาสตร์
n = int(input()) #number for n! (int)

# Process : กำนหดค่า n_min , n_max
n_floor = math.sqrt(2*math.pi) * n**(n+0.5) * math.exp(-n + 1/((12*n)+1))
n_ceil = math.sqrt(2*math.pi) * n**(n+0.5) * math.exp(-n + 1/(12*n))

# Output : print ขอบบน , ขอบล่าง ของ n!
print(n_floor) #float
print(n_ceil) #float

## อย่าลืม!! เวลาเอาไปลงใน Grader -> ลบ command ใน input() ออกด้วย

# Test Case : 
# case 1 : n = 1 -> 1! -> n_floor = 0.995870161462797 , n_ceil = 1.0022744491822266
# case 2 : n = 5 -> 5! -> n_floor = 119.96985395920886 , n_ceil = 120.00263708619694
# case 3 : n = 50 -> 50! -> n_floor = 3.041400953459947e+64 , n_ceil = 3.041409387750485e+64
# case 4 : n = 100 -> 100! -> n_floor = 9.332615094728949e+157 , n_ceil = 9.332621570317617e+157
# Out:
# 3628560.141985109
# 3628810.0514269313

# %% [markdown]
# ### Solution 01_01 : Stirling Factorial (1 Star)

# %%
# 1 : import math + รับค่า n (int) เพื่อหา n!
import math
n = int(input('Enter number for n! : '))

# 2 : เข้าสูตร เพื่อหาค่า lower & upper ของ n!

lower = math.sqrt(2*math.pi) * (n ** (n + 0.5)) \
    * math.e**(-n + (1/ (12*n + 1) )) # \ คือขึ้นบรรทัดใหม่
            
upper = math.sqrt(2*math.pi) * (n ** (n + 0.5)) \
    * math.e**(-n + (1/ (12*n) )) # \ คือขึ้นบรรทัดใหม่
    
# 3 : print ค่าออกมา
print('Lower of n! is : ' , lower)
print('Upper of n! is : ' , upper)

## อย่าลืมลบคำพูดออกใน grader
# Out:
# Lower of n! is :  3628560.141985111
# Upper of n! is :  3628810.051426933

# %% [markdown]
# ### Task 01_02 : Quadratic Root (1 Star)
# ![01_02 Quadratic Roots.png](attachment:d56f8515-92f8-445e-93f0-5494281c1666.png)

# %%
# Step : 
# 1. รับค่า a,b,c เพื่อเข้ารูปสมการ ax^2+bx+c = 0
# 2. เข้าสูตรเพื่อหาค่า x -> มี x 2 คำตอบ
# 3. print ค่า x และ round ค่า

# Input : a , b , c (float) , import math module
import math
a = float(input()) #x^2 degree #float
b = float(input()) #x^1 degree #float
c = float(input()) #x^0 degree #float

# Process : เข้าสูตร quadratic
x_1 = (-b - math.sqrt( (b**2) - (4*a*c) )) / (2*a)
x_2 = (-b + math.sqrt( (b**2) - (4*a*c) )) / (2*a)

# Output : print & round !! บรรทัดเดียวกัน อย่าลืม !!
print( round(x_1 , 3) , round(x_2 , 3) ) #ค่าซ้ายเป็น x1 ค่าขวาเป็น x2

## ถ้า b^2 - 4ac = 0 -> ระบบจะบอกว่า math domain error
## วิธีเเก้ -> เราจะทำการเช็ค b^2 - 4ac (discriminant) ก่อน
## ถ้า b^2 - 4ac มากกว่า หรือ เท่ากับ 0 -> ให้ output x1 , x2 ออกมา
## ถ้า b^2 - 4ac น้อยกว่า 0 -> บอก user ว่า "Error"

# test case (case เดิม)
# case 1 : a = 1 , b = -5 , c = 6 -> x^2 -5x + 6 = 0        -> x_1 = 2 , x_2 = 3 (x_1 < x_2)
# case 2 ; a = 1 , b = -1 , c = 42 -> x^2 -x -42 =  0       -> x_1 = -6 , x_2 = 7 (x_1 < x_2)
# case 3 ; a = 6 , b = -4 , c = -12 -> 6x^2 -4x -12 =  0    -> x_1 = -1.12 , x_2 = 1.786 (x_1 < x_2)
# case 4 ; a = 20 , b = -50.5 , c = -21.2 -> 20x^2 -50.5x -21.2 =  0 -> x_1 = -0.367 , x_2 = 2.892 (x_1 < x_2)
# Out:
# -10.107 9.087

# %%
## ปรับปรุง code : 01_02 Quadratic Roots
# Step 1 : รับ input a,b,c (float) แทนดีกรี x^2 , x^1 , x^0 ตามลำดับ + import math
import math
a = float(input()) #x^2 degree (float)
b = float(input()) #x^1 degree (float)
c = float(input()) #x^0 degree (float)

# Step 2 : check discriminant first
if (b**2) - (4*a*c) >= 0 : 
    # 2.1 : define x_1 , x_2
    x_1 = (-b - math.sqrt( (b**2) - (4*a*c) )) / (2*a)
    x_2 = (-b + math.sqrt( (b**2) - (4*a*c) )) / (2*a)
    # 2.2 : print & round x_1 , x_2
    print( round(x_1 , 3) , round(x_2 , 3) )
    
else : # 2.3 : b^2 - 4ac < 0 -> complex nb. answer
    print('No Real Number Answers, Error 404')
    
# test case :
# case 1 : a = 1 , b = 5 , c = 6 -> x^2 + 5x + 6 = 0 -> x1 = -2 , x2 = 3 
# case 2 : a = 4 , b = 6 , c = 8 -> 4x^2 + 6x + 8 = 0 -> No Real Number
# Out:
# -1.0 -1.0

# %% [markdown]
# ### Solution 01_02 : Quadratic Roots (1 Star)

# %%
# Logic : เเก้สมการกำลัง 2

# 1 : รับค่า a,b,c (float) + import math
import math
a = float(input('Input A for x^2 degree : ')) #float
b = float(input('Input B for x^1 degree : ')) #float
c = float(input('Input C for x^0 degree : ')) #float

# 2 : เข้าสูตร เเก้สมการ
discriminant = (b*b - 4*a*c) 

## ระวัง ! อย่าลืมดูดีๆ ว่าเรา input data ประเภทไหนเข้ามา (str*str ทำ math op. ไม่ได้)

x1 = ( -b + math.sqrt(discriminant) ) / (2*a)
x2 = ( -b - math.sqrt(discriminant) ) / (2*a)

ans1 = round(x1 , 3)
ans2 = round(x2 , 3)

# 3 : print x1 , x2
print('Answer 1 : ' , ans1 , 'Answer 2 : , ' , ans2) #print บนบรรทัดเดียวกัน

## จริงๆเราสามารถยุบ การ round ใน x1 , x2 ได้เลย
# Ex : 
# Ex : 

## อย่าลืม ! ฝึกการคิด testcases ไว้ว่าสามารถเกิดอะไรขึ้นได้บ้าง เเล้วดูว่าเราผิดตรงไหน
# Out:
# Answer 1 :  1.0 Answer 2 : ,  1.0

# %% [markdown]
# ### Task 01_03 : Strange Expression (2 Star)
# ![01_03 Expression.png](attachment:8bb371a7-bbf0-4b43-bb74-cc8cbfb37704.png)

# %%
# Step : 
# 1. เเทนสูตรลง a -> เข้าสูตรดีๆ ระวังผิดพลาด ( เรื่อง math fn กับ () )
# 2. round ค่าออกมา

# Step 1 : เเทนลง ตป. & เข้าสูตร !!!!!อย่าลืม import math ด้วยยยย!!!!
# จากรูปสมการ เราจะทำให้อยู่ในรูป answer = (a + b) / c เพื่อกันสับสน
import math
a = math.pi - ( math.factorial(10) / (8**8) ) 
b = math.log(9.7) ** ( (7/math.sqrt(71) - math.sin(40/180 * math.pi)) ) # ส่วน 'เศษ'
c = 1.2 ** (2.3 ** (1/3)) # ส่วน "ส่วน"
answer = (a + b) / c

# ระวัง 1 : ใช้ 10! ไม่ได้ ต้องใช้เป็น math.factorial(10)
# ระวัง 2 : log ปกติใน python ถ้าไม่ใส่ฐาน จะใช้ฐาน e -> คำสั่ง : math.log(a,base)
# ระวัง 3 : ใน math.sin() มุมด้านในจะเป็น rad -> แปลง deg เป็น rad ก่อน -> 40 องศา = 2pi/9 (pi = 180 องศา) หรือจะใช้ math.radians() ก็ได้

# Step 2 : print & round ค่าตัวเเปร
print( round(answer , 6) )

## เวลาเอาลง grader -> ใส่คำสั่งลงบรรทัดเดียวกัน
# Out:
# 3.216814

# %% [markdown]
# ### Solution : 01_03 Strange Expression (2 Star)

# %%
# Key : เเยกคิดทีละส่วน กันสับสน

# 1 : import math 
import math

# 2 : เเยกคิดทีละส่วน
a = math.factorial(10) / (8 ** 8)
b = math.log(9.7 , math.e) # ปกติเป็นฐาน e ไม่ต้องใส่ฐานก็ได้ (cmd : math.log(x,base)) ## ใช้เป็น math.e naja
c = (7 / math.sqrt(71)) - math.sin(40/180 * math.pi) # หรือจะใช้ math.radians(40) ก็ได้
d = 1.2 ** ((2.3) ** (1/3))

##  ระวังมุม 40 องศา => math.sin() ใช้หน่วย rad -> เเปลงเป็น rad ก่อน เเล้วค่อยใช้

# 3 : รวมร่าง
ans = (math.pi - a + (b ** c) )/d

# 4 : print ans
print( round(ans , 6) )
# Out:
# 3.216814

# %% [markdown]
# ### Task 01_04 : Body Surface Area (2 Star)
# ![01_04 Body Surface Area.png](attachment:0b79a7d1-67b2-4ede-adba-8e0cc9cb4ab1.png)

# %%
# Logic : เเปลง W,H ให้เข้าสูตร เพื่อหา Area (m^2)
# Step :
# 1. รับ input W (float), H_cm (float) เข้ามา 
# 2. เขาสูตรการหา Area เเต่ละคน !! ระวัง เครื่องหมาย & fn ทางคณิตศาสตร์ ดีๆ !!
# 3. print area ของเเต่ละคนออกมา

# Input : W (float) , H (float) & import math ด้วย เผื่อใช้ fn ทางคณิตศาสตร์
import math
W = float(input()) #input weight (kg)
H = float(input()) #input height (cm)

# Process : เข้าสูตรคำนวณ Area
area_mosteller = math.sqrt(W*H) / 60
area_haycock = 0.024265 * (W**0.5378) * (H**0.3964)
area_boyd = 0.0333 * ( W ** ( 0.6157- (0.0188 * math.log(W,10)) ) ) * (H**0.3)

# ระวัง 1 : ยกกำลัง ใช้เครื่องหมาย ** อย่าไปใช้ ^ เพราะให้ค่าทางคณิตศาสตร์ต่างกัน
# ระวัง 2 : ฟังก์ชั่น log ปกติเป็นฐาน e เราเลยต้องใส่ฐานให้ด้วย ดัง command math.log(a,base)

# Output : print ค่า area ของเเต่ละคนออกมา
print(area_mosteller) #m^2
print(area_haycock) #m^2
print(area_boyd) #m^2
# Out:
# 1.685724374465371
# 1.690204220228866
# 1.7016366159786662

# %% [markdown]
# ### Solution : 01_04 Body Surface Area

# %%
# Key : รับ W&H -> เข้าสูตร เพื่อหา Body Surface Area

# 1 : รับ input W,H (float) + import math
import math
W = float(input('Enter Weight : '))
H = float(input('Enter Height (m) : '))

# 2 : เข้าสูต่ร Body Surface Area
mosteller = (W*H) ** 0.5 / 60
haycock = 0.024265 * (W**0.5378) * (H**0.3964)
boyd = 0.0333 * (W ** (0.6157 - 0.0188*math.log(W,10))) * (H**0.3)

# 3 : print ค่าเเต่ละสูตร
print('Mosteller : ', mosteller , 'm^2') #float
print('Haycock : ' , haycock , 'm^2') #float
print('Boyd : ' , boyd , 'm^2') #float

# Tips : เขียนเว้นวรรค + เว้นบรรทัด + วงเล็บ => เวลากลับมาทวนจะง่ายขึ้น
# Out:
# Mosteller :  1.632993161855452 m^2
# Haycock :  1.6405263078886525 m^2
# Boyd :  1.6559442139404335 m^2

# %% [markdown]
# ### Task 01_05 : Duration (3 Star)
# ![01_05 Duration.png](attachment:7e36e824-1932-4ea2-90bb-cfb78d2c4640.png)

# %%
# Logic : หา ช่วงเวลาที่ต่างกัน (เเปลงเป็น sec ก่อน เเล้วเเปลงเป็น  ้พ)
# Step : 
# 1. รับค่า h1,m1,s1 เเละ h2,m2,s2 (int)  
# 2. เเปลงค่า h,m,s ให้เป็น t1 , t2 ตามลำดับ
# 3. define ตป. dt (difference time) = t2 - t1
# 4. เเปลง dt ให้เป็น dh,dm,ds (หารปัดเศษ)
# 5. เเปลงค่า dh จาก - ให้เป็น + => (24 - dh)

# Step 1 : รับ input h1,m1,s1,h2,m2,s2 (int)
h1 = int(input()) 
m1 = int(input())
s1 = int(input())

h2 = int(input())
m2 = int(input())
s2 = int(input())

# Step 2 : เเปลงค่า h,m,s เป็น t 
t1 = h1*60*60 + m1*60 + s1 #time total (sec) initial
t2 = h2*60*60 + m2*60 + s2 #time total (sec) final

# Step 3 : define dt (t_final - t_initial) & check เงื่อนไข t2 กับ t1
dt = t2 - t1

if t2 < t1 :
    dt = 86400 + (t2 - t1) #บวกไป 1 วัน เพื่อเกิดเศษวัน

# Step 4 : แปลง dt ให้เป็น dh , dm , ds
dh = dt // (60*60) #หารปัดเศษ 3600 sec -> เอา จน.hr
dt = dt - (dh * 3600) #ลบ จน.ชั่วโมงออก เหลือเศษ hr (sec) ## ตอนนี้ dt เหลือเศษ hr เเล้ว -> เเปลงต่อเป็น m,s

dm = dt // 60 #หารปัดเศษ 60 sec -> เอา จน. min
dt = dt - (dm * 60) #ลบ จน.นาทีออก เหลือเศษ min (sec) ## ตอนนี้ dt เหลือเศษ min แล้ว-> ไม่ต้องเเปลงต่อเเล้ว เพราะที่เหลือเป็นหน่วย sec

ds = dt #เศษ min = จน.sec ที่เหลือ กำหนดให้เป็น ds ได้เลย

# Step 5 : print ตาม format โจทย์
print( str(dh) + ':' + str(dm) + ':' + str(ds) ) #เขียนใน format HH : MM : SS


## ลองเอาไป run ใน grader เเล้ว

# Note : Sol 1 : ลองใช้ dt = abs(t2 - t1) ได้เเค่ 40 pts เเสดงว่า ยังมีปัญหาอยู่ในบาง testcases -> ลองใช้ mod ดู (น้ำเอกเเนะนำ)
#        Sol 2 : เจอปัญหาว่า dt เป็นลบอยู่ -> เเก้โดย + 24 เข้าไป -> dh = 24 + (h2-h1) -> ได้ 50 คะเเนน -> ยังมีปัญหาอยู่
#        Sol 3 : เจอปัญหาว่า dt เกิน 25 ชม.ได้ -> เเก้โดย mod 24 เพื่อให้ไม่เกิน 24 -> ได้ 70 คะเเนน -> เดะเช็คบาง testcases ที่ผิด 
#        Sol 4 : ตอนนี้เจอปัญหาว่า dh เกินมา 1 ตลอด (ถ้า 23 -> โชว์ 0 , ถ้า 1 -> โชว์ 2)

#        Sol 5 : ถ้าหาก t2 < t1 -> เวลาจะติดลบ -> เราจะบวกเพิ่มไป 1 วัน เพื่อทำให้เกิดเศษวัน -> เเล้วเเปลงเป็น h,m,s => 100 ja
# Out:
# 3:3:2

# %% [markdown]
# ### Solution : 01_05 Duration (3 Star) By Dr.Somchai

# %%
## Solution By SPJ
## เจอปัญหาว่า dh = ผลต่างจน.ชม. เป็นลบ => เเก้โดย +24 เเล้ว mod 24 เพื่อให้เป็น + (เเต่มันใช้ได้เเค่ชม.)
## เราต้องการวินาทีออกมา -> ใช้วิธีเดียวกันกับ dh เเต่จะสร้างตป.จน.วินาทีใน 1 วัน (86,400)ขึ้นมา

# 1 : รับ input h,m,s เข้ามา
h1 = int(input())
m1 = int(input())
s1 = int(input())
h2 = int(input())
m2 = int(input())
s2 = int(input())

# 2 : หาผลต่างเวลา + ตั้ง ตป. sec_in_day ขึ้นมา
# 2.1 : เเปลงเป็นวินาทีให้หมดก่อน
t1 = 3600*h1 + 60*m1 + s1 #sec
t2 = 3600*h2 + 60*m2 + s2 #sec
dt = t2 - t1

# 2.2 : เเปลงสูตร โดยที่ผลต่างเป็น + & ไม่เกิดเคสเศษเกิน
    # เเปลงรอบเเรก : +86,400 ให้เป็นค่า + (ถ้าเกิน ก็ mod 86400 จะเหลือ dt)
dt = (86400 + t2 - t1)
    # แปลงรอบ 2 : mod 86400 -> ได้ dt
dt = dt % 86400 

# 3 : เเปลง dt ให้อยู่ในรูป h,m,s
dh = dt // 3600 # หารปัดเศษ เอา hr
dt = dt - (3600*dh)

dm = dt // 60 # หารปัดเศษ เอา min
dt = dt - (60*dm)

ds = dt

# 4 : print ตาม format
print(str(dh) + ':' + str(dm) + ':' + str(ds))
# Out:
# 3:0:55

# %% [markdown]
# ### Task 01_06 : Body Surface Area (Function) (1 Star)
# ![01_06 BSA (Function).png](attachment:bf9f0f93-d0c1-476e-a44e-78bf028e5a66.png)

# %%
# Logic : เรียกใช้ fn โดยการสร้าง 3 fn ก่อนหน้า เเล้วเรียก fn รวมใน fn main

# Step 1 : สร้างเเต่ละ function ขึ้นมา

def mosteller(weight,height) : # weight,height เป็น  parameter (มีไว้เนื่องจากเราจะทำการเรียกตอน fn main)
    mosteller_area = ((weight * height) ** 0.5) / 60
    # เราจะต้องทำการ return ค่าออกมาด้วย (ระวังว่า ตป.ไม่ควรซ้ำกับชื่อฟังก์ชั่น)
    return mosteller_area
    
def du_bois(weight,height) :
    du_bois_area = 0.007184 * (weight ** 0.425) * (height ** 0.725)
    # เราจะต้องทำการ return ค่าออกมาด้วย (ระวังว่า ตป.ไม่ควรซ้ำกับชื่อฟังก์ชั่น)
    return du_bois_area

def fujimoto(weight,height) :
    fujimoto_area = 0.008883 * (weight ** 0.444) * (height ** 0.663)
    # เราจะต้องทำการ return ค่าออกมาด้วย (ระวังว่า ตป.ไม่ควรซ้ำกับชื่อฟังก์ชั่น)
    return fujimoto_area

# Step 2 : สร้าง fn main ขึ้นมา

# For What ? : เพราะสามารถเรียกค่า 3 สูตรได้พร้อมกัน & เพื่อทำการรับ input น้ำหนัก & ส่วนสูง เข้ามา

def main() :
    # step 2.1 : รับ input weight & height เข้ามา
    weight = float(input())
    height = float(input())
    
    # step 2.2 : เรียก fn ที่เขียนก่อนหน้านี้ (เรียกด้วย ชื่อfn(parameter) )
    mosteller_area = mosteller(weight , height) # เราเรียกฟังก์ชั่น โดยการเเทน parameter ด้วยค่าที่ input เข้าไปใน fn main
    du_bois_area = du_bois(weight , height) # เราสามารถใช้ parameter เดียวกันกับ 3 fn ก่อนๆได้
    fujimoto_area = fujimoto(weight , height)
    
    # step 2.3 : print ค่า & round ค่า 5 ตน. ตามโจทย์
    
    print('Mosteller =' , round(mosteller_area,5) )
    print("Du Bois =" , round(du_bois_area,5) )
    print("Fujimoto =" , round(fujimoto_area,5) )
    
# Step 3 : execute คำสั่ง
exec(input()) #อธิบายง่ายๆ คือ เราป้อนคำสั่งเป็น str เพื่อทำให้โค้ดประมวลผลออกมา
# ex : ป้อนค่า "print('5')" เข้าไป ระบบจะแสดง 5 ออกมา (เอาไว้ตรวจสอบ testcases)
# ex : ป้อนค่า "main()" เข้าไป ระบบจะไปรัน fn main ทันที


## Note : ถ้าเรา print ค่า 3 fn จะได้ว่า ค่าจะไม่ปัดเศษ เพราะเราไม่ได้ round สูตรให้เป็น 5 ตน. ใน fn นั้น
## เเต่ถ้าเราเรียก fn main() จะเกิดการ round ค่าขึ้น
# Out:
# Mosteller = 1.64046
# Du Bois = 1.66698
# Fujimoto = 1.61651

# %% [markdown]
# ### Task 01_07 : Cube Root (Function) (2 Star)
# ![01_07_01 Cube Root (Function).png](attachment:c60c7b86-9ea0-4152-a9f5-8f0f8c81d777.png)
# ![01_07_02 Cube Root (Function).png](attachment:a02d3c33-0e45-4a35-aaf9-3d27cab9418e.png)

# %%
# 1 : สร้าง fn sqrt_n (parameter x,n)
def sqrt_n_times(x,n) : # คืนค่า √
    ## Logic : หารูปทั่วไป ของ √√√...x = x^(1/2^n) ; n = จน.sqrt
    return x ** (1/(2**n))
   
# 2 : สร้าง fn cube root (parameter y) 
def cube_root (y) :
    # คืนค่า y ** ((1/2^2)(1 + 1/2^2)(1 + 1/2^4)(1 + 1/2^8)(1 + 1/2^16)(1 + 1/2^32))
    # Logic : สังเกตว่า ยกกำลังซ้อนไปเรื่อยๆ => เเล้วยัด fn ลงไป
    
    y1 = sqrt_n_times(y,2) # y ** (1/2^2)
    y2 = y1 * sqrt_n_times(y1,2)    # เอา y1 มา ** (1 + 1/2^2) = y1 * (y1**(1/2^2)) = y1 * fn sqrt
    y3 = y2 * sqrt_n_times(y2,4)    # เอา y2 มา ** (1 + 1/2^4) = y2 * (y2**(1/2^4)) = y2 * fn sqrt
    y4 = y3 * sqrt_n_times(y3,8)    # เอา y3 มา ** (1 + 1/2^8) = y3 * (y3**(1/2^2)) = y3 * fn sqrt
    y5 = y4 * sqrt_n_times(y4,16)   # เอา y4 มา ** (1 + 1/2^16) = y4 * (y4**(1/2^2)) = y4 * fn sqrt
    y6 = y5 * sqrt_n_times(y5,32)   # เอา y5 มา ** (1 + 1/2^32) = y5 * (y5**(1/2^2)) = y5 * fn sqrt
    
    # 2.1 : define cube_root
    cube_value = y6 # ค่าสุดท้ายหลังจากเข้าสูตร
             
    # 2.2 : return cube_value
    return cube_value

# 3 : define fn main : รับ input & เรียก fn cube_root
def main() :
    q = float(input('Enter Number : '))
    print(cube_root(q)) # เรียก fn cube_root ออกมา
    
# 4 : exec input เพื่อ check fn
exec(input())
# Out:
# 2.999999999999999

# %% [markdown]
# ### Task 01_08 : Duration (Function) (2 Star)
# ![01_08 Duration (Function).png](attachment:a81b3b3a-c20d-4965-8790-05505e495440.png)

# %%
##### Part 1 : function str2hms คู่กับ hms2str

# 1 : สร้าง fn : เเปลง HH:MM:SS => H (int) , M (int) , S (int)
def str2hms(hms_str):
    t = hms_str.split(':')
    return int(t[0]) , int(t[1]) , int(t[2])

# 2 : สร้าง fn : เเปลง H (int) , M (int) , S (int) ==> HH:MM:SS
def hms2str(h,m,s) :
    return ('0' + str(h))[-2:] + ':' + \
           ('0' + str(m))[-2:] + ':' + \
           ('0' + str(s))[-2:]
           
# -----------------------------------------------------------------    

##### Part 2 : สร้าง HMS -> sec คู่กับ sec -> HMS

# 3 : fn เปลี่ยน H (int) , M (int) , S (int) -> sec_total
def to_sec(h,m,s) :
    sec_total = 3600*h + 60*m + s
    return sec_total

# 4 : fn เปลี่ยน sec_total ->  H (int) , M (int) , S (int)
def to_hms(s):
    h = s // 3600
    s = s - (3600*h)
    m = s // 60
    s = s - (60*m)
    s = s
    return h,m,s # int , int , int

# ------------------------------------------------------------------

# 5 : fn เทียบความต่างออกมา ==>  ป้อน HH:MM:SS เข้ามา return h , m , s
def diff(h1,m1,s1,h2,m2,s2):
    t1 = to_sec(h1,m1,s1)
    t2 = to_sec(h2,m2,s2)
    dt = (86400 + t2 - t1) % 86400 ## Key : บวกค่า เศษ +,- วินาทีไป +1 วัน ==> ได้จน.วิ (~80K) => หารเอาเศษ จน.วินามีใน 1 วัน จะได้ 
    ds = to_hms(dt)
    
    return ds # h,m,s

# 6 : fn main() ==> เรียกทุก fn ออกมา
def main() :
    
    # 6.1 : รับ input HH:MM:SS เข้ามา 
    hms_start_str = input('Enter Start HH:MM:SS Time : ') #str
    hms_end_str = input('Enter End HH:MM:SS Time : ') #str
    
    # 6.2 : เเปลง HH:MM:SS ให้เป็น H (int) , M (int) , S (int)
    hs , ms , ss = str2hms(hms_start_str)
    he , me , se = str2hms(hms_end_str)
    
    # 6.3 : เรียก fn diff => ได้ค่า จน. dh , dm , ds ออกมา
    diffh , diffm , diffs = diff(hs,ms,ss,he,me,se) # sec
    
    # 6.4 : เรียก fn hms2str => ได้ str ในรูป HH:MM:SS ออกมา 
    time_hms = hms2str(diffh , diffm , diffs)
    
    # 6.5 : print ค่า final ออกมา (return จะไม่ออกค่า เพราะเรารับ input ใน fn นี้ เลยต้อง print ออกมา)
    print(time_hms)
    
# 7 : exec input เพื่อ check fn
exec(input())
# Out:
# 00:02:03

# %% [markdown]
# ### Task 01_09 : Songkran (1 Star)
# ![Expression_01 Songkran.png](attachment:096359a0-bc51-4349-8abd-5bdb763fcffc.png)

# %%
# 1 : y_en -> y_th
y_th = int(input('Enter Buddha Year : '))

# 2 : เเปลง type เป็น str -> เเปลงค่า
y_en = y_th - 543
y = str(y_en)[2::1] # เอา 2 ตัวท้าย -> เริ่มตัว index 2

# 3 : เข้าสูตร
week = ( (int(y) + ( int(y) // 4) + 11) ) % 7 # หารเอาเศษ 7 เพราะต้องการเศษ 1-6 (วันของสัปดาห์)
print(week)
# Out:
# Enter Buddha Year :  2567
# 6

# %% [markdown]
# ### Task 01_10 : Strange Expresssion (1 Star)
# ![Expression_02 Strange Exp..png](attachment:6264ebcd-87a3-4a1d-84d8-5fd07ff83b89.png)

# %%
# 1 : input + import math
import math
x = float(input('Enter Number : '))

# 2 : เข้าสูตร
ses = x ** math.sqrt( math.log((x+1)**2 , math.e) ) # อย่าลืม math.e
suan = 10 - x
y = ses / suan

# 3 : print & round y 
print( round(y*1e6)/1e6 )
# Out:
# Enter Number :  1.9
# 0.314983

# %% [markdown]
# ### Task 01_11 : Eyeball (2 Star)
# ![Expression_03 Eyeball.png](attachment:bb35fe74-ffa0-4a4f-b1df-30a1f452f7fb.png)

# %%
# 1 : input in same line -> list comp.
xe , ye , re , rp , xm , ym = [int(e) for e in input('Enter Info : ').split()]

# 2 : from problems => seeing similar triangles : we know A,B,C,c

### full triangle -> A = (xm-xe) , B = (ym-ye) , C = A^2 + B^2
### grey triangle -> using properties of similar triangles ===> compare each side with c (cuz we know c)

    # b / c = B / C => b = (B/C) * c
    # a / c = A / C => a = (A/C) * c

# 2.1 : Full Triangle
A = (xm - xe) # difference of x-axis 
B = (ym - ye) # difference of y-axis
C = (A**2 + B**2) ** 0.5

# 2.2 : Small Triangle
c = re - rp
b = (B/C) * c
a = (A/C) * c

# 3 : find (xp , yp) => xp = xe + a , yp = ye + b
xp = xe + a
yp = ye + b

# 4 : print & round xp, yp
print( round(xp) , round(yp) )
# Out:
# 47 47

# %% [markdown]
# ### Task 01_12 Trigonometry Expression (1 Star)
# ![Expression_04 Trigon Expression.png](attachment:da0c8bfa-ea4a-48a5-a8b0-35bf5fd96f79.png)

# %%
# 1 : import math + input x
import math
x = float(input('Enter X : '))
x_deg = x # ให้มุมเป็น x degree

# 2 : มองทีละก้อน + เเปลงมุม deg -> rad (math.cos / math.sin ใช้ radian)
x_rad = x_deg / 180 * math.pi # x มีค่าเหมือน x_deg

ses = math.sqrt( x**2 + (math.cos(x_rad)**2) )
suan = math.sin(x_rad) + ( (math.cos(x_rad))**3 / (x**2 + 1) )
total = ses / suan

# 3 : output
print('Result of X : ' , round(total,1) )
# Out:
# Result of X :  5.4

# %% [markdown]
# ### Task 01_13 : Projectile Motion (1.5 Star)
# ![Expression_05 Projectile.png](attachment:636f7319-ddba-4270-ae2f-7d83669db634.png)

# %%
# 1 : input velocity , theta , time + import math
import math
velocity , theta_deg , time = [float(e) for e in input('Enter u , θ , t : ').split()]
g = 9.81 # vertical acceleration value

# 2 : transform deg to rad
theta_rad = theta_deg * (math.pi / 180)

# 3 : find h,r by substitute value ( condition : 0 < theta < 90 deg )
if 0 <= theta_deg <= 90 :
    left = (time - (velocity * math.sin(theta_rad)/g) )
    right1 = velocity * math.sin(theta_rad) 
    right2 = (0.5 * g * (time - (3 * velocity * math.sin(theta_rad / g) ) ) )

    height = left * (right1 + right2)
    range = velocity * math.cos(theta_rad) * time
    
    print( round(height*10)/10 , round(range*10)/10 )

else :
    print('Not a Projectile Motion')
# Out:
# 411.6 70.7
