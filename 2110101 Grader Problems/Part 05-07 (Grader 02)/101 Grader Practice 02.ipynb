# %% [markdown]
# # 2110101 Grader Problems
# ## Solution by : Nine #1 General (Gr.E)
# ## Grader Practices For Exam #02 (Basic Problems)

# %% [markdown]
# ## Overview
#
# - P2_01 : Odd-Odd Functions (2 Star) ☑️
# - P2_02 : Card (2 Star) ☑️
# - P2_03 : Potpurri Functions (2.5 Star) ☑️ 75%
# - P2_04 : Delivery (3 Star) ☑️ 45%
# - P2_05 : Anagram Ver.2 (3 Star)
# - P2_06 : Morse Code (3 Star) ☑️ 60%
# - P2_07 : Snooker (2 Star)
# - P2_08 : Thai Numerals (2.5 Star) ☑️
# - P2_09 : Vitamin (3 Star)

# %% [markdown]
# ### Task P2_01 : Odd-Odd Functions (2 Star)
# ![P2_01 Odd odd Functions.png](attachment:d723f52e-4b3d-45a6-af16-40fa6819c077.png)

# %%
# 1 : define 6 functions
def is_odd(n): # parameter = n = int , return T/F
    if n % 2 != 0 : # is odd -> return T
        return True
    # if not -> return F
    return False

def has_odds(x) : # parameter = x = list , return T/F
    # for loop -> check ele if that ele are odd
    for i in range(len(x)) :
        if x[i] % 2 != 0 :
            return True
    # out of loop -> if not return T -> return F
    return False

def all_odds(x) : # parameter = x = list , return T/F
    # for loop -> check ele if that ele are odd
    for i in range(len(x)) :
        if x[i] % 2 == 0 :
            # if some element are even -> return F
            return False
    # out of loop -> if all are even -> return True
    return True

def no_odds(x) : # parameter = x = list , return T/F
    # for loop -> check ele if all ele are not odd
    for i in range(len(x)) :
        if x[i] % 2 != 0 :
            # if some element are odd -> return F
            return False
    # out of loop -> if all are even -> return True
    return True

def get_odds(x) : # parameter = x = list , return odd_list (list)
    # append to odd_list if found odd
    odd_list = []
    # for loop -> if found odd -> append
    for i in range(len(x)) :
        if x[i] % 2 != 0 :
            odd_list.append(x[i])
    # out of for loop -> return list
    return odd_list

def zip_odds(a,b) :
    # Logic : add odd nbs to odd_lista , odd_listb
    odd_lista = [] ; odd_listb = []
    # for loop 2 list -> add odd ele.
    for i in range(len(a)) :
        if a[i] % 2 != 0 : odd_lista += [ a[i] ]
    for j in range(len(b)) :
        if b[j] % 2 != 0 : odd_listb += [ b[j] ]  
    # insert each ele of odd_a to odd_b
    k = 0
    for ele in odd_lista :
        odd_listb.insert( k , ele ) # first insert at index 1
        k += 2 
    # out of loop -> return odd_listb
    return odd_listb

# 2 : execute fn
exec(input().strip()) # strip for error
# Out:
#  print(is_odd(31))
# True

# %% [markdown]
# ### Task P2_02 : Card (2 Star)
# ![P2_02 Card.png](attachment:1a538a47-29bd-4b1e-92d1-1c735b754a28.png)

# %%
# 1 : define fn for reading value
def diff_card(info1 , info2):
    # 1.1 : read first digit of card
    value_card = ['A','2','3','4','5','6','7','8','9','T','J','Q','K']
    set_card = ['C','D','H','S']
    # 1.2 : check if first digit is same or not
    
    # case 1 : same first digit -> consider diff only second digit (set_card)
    if info1[0] == info2[0] : 
        diff = 0 + ( set_card.index(info1[1]) - set_card.index(info2[1]) )
        
    # case 2 : different first digit -> consider diff first digit only
    elif info1[0] != info2[0] :
        diff = ( value_card.index(info1[0]) - value_card.index(info2[0]) ) + 0
        
    # 1.3 : return diff
    return diff # int

# 2 : consider card in our hand
cards_info = input().strip() # strip for error 
diff_out = ''

# 2.1 : check loop -> Logic : loop until len - 3 (cuz consider i,i+1,i+2,i+3) , step 2
for i in range(0 , len(cards_info) - 2 , 2) :
    # 2.1.1 : check value positive or negative
    diff = diff_card( cards_info[i:i+2] , cards_info[i+2:i+4] ) # (i&i+1) <-> (i+2 , i+3)
    if diff > 0 :
        diff_out += '+' + str(diff)
    else :
        diff_out += str(diff)
        
# 3 : out of loop -> print diff (strip too)
print(diff_out.strip())
# Out:
# -4-2

# %% [markdown]
# ### Task P2_03 : Potpurri Functions (2.5 Star)
# ![P2_03 Pottpurri Functions_01.png](attachment:b63e3083-f4cb-4f92-80e2-05d85c376861.png)
#
# ![P2_03 Pottpuri Functions_02.png](attachment:8e510300-07dc-4791-8dfe-6687ca2410cb.png)

# %%
# 1 : create 4 fns
def convex_polygon_area(p) : # parameter = p , return area (float)
    # p is list (of list)
    
    # 1 : add first element for completing cycle (change parameter)
    p += [ p[0] ] # add element for calculating polygon
    
    # 2 : find determinant
    det_plus = 0 ; det_minus = 0 # define det first
    
    for i in range(len(p) - 1) :
        det_plus += (p[i][0] * p[i+1][1]) # x_n * y_n+1
        det_minus += (p[i+1][0] * p[i][1]) # x_n+1 * y_n
        
    # out of loop -> calculate area
    area = abs(0.5 * (det_plus - det_minus))
    return area # float
        
def is_heterogram(s) : # check if string is repeated
    # 1 : change back to lower for safe + define bool (check_same)
    s.split()
    str_s = '' ; list_alphabet = []
    for i in range(len(s)) : # add lower string (no strange symbol)
        if s[i] not in ' \'[]"<>.,!@#$%^&*()\\/' :
            str_s += s.lower()[i]
    
    # 2 : for loop & check if that ele in string
    for i in range(len(str_s)) :
        if str_s[i] not in list_alphabet : 
            list_alphabet += [ s.lower()[i] ]
        elif str_s[i] in list_alphabet : # if 
            return False
    # if not in list -> no repeated char -> return True
    return True
    
def replace_ignorecase(s,a,b) :
    # s = string , a = want to change , b = changing word
    # Logic : loop -> if found b in a -> replace until not found
    
    # 1 : for loop (str) 
    for i in range(len(s)) :
        if a.lower() == s.lower()[i:i+len(a)] :
            s = s.replace(a , b)
    return s

    # 2 : 


    # import re
    # return re.sub(a, b, s, flags=re.IGNORECASE)
    
def top3(votes) :
    # 1 : create list_top3 first (for adding key into list)
    list_top3 = []
    # 2 : sort (.items()) (will give list) then dict() -> will give dict
    votes = dict(sorted(votes.items()))
    # 3 : for loop 3 times -> we need 3 element
    for i in range(3) : 
        # 4 : find key -> using max(dict , key = dict.get())
        top_key = max(votes , key = votes.get) # get key from dict with using max fn
        # 5 : add key into list
        list_top3 += [top_key]
        # 6 : give max value to 0 -> for next compare
        votes[top_key] = 0
    # 7 : out of loop -> return list
    return list_top3

# execute fn
for k in range(2):    
    exec(input())

# %% [markdown]
# ### Task P2_04 : Delivery (3 Star)
# ![P2_04 Delivery.png](attachment:ddadd7ac-558f-498e-ae9d-8970d412f978.png)

# %% [markdown]
# ### Task P2_05 : Anagram Ver.2 (3 Star)
# ![P2_05 Anagram II.png](attachment:9c9990ab-86f7-4ec8-bb39-68d32c58e174.png)

# %%
# 1 :

# %% [markdown]
# ### Task P2_06 : Morse Code (3 Star)
# ![P2_06 Morse Code_01.png](attachment:0cad4b3f-c89b-44f7-93d6-67437e2d67f4.png)
#
# ![P2_06 Morse Code_02.png](attachment:60ff07f6-7f6d-4d8c-9376-bc6fd46cb4ad.png)

# %% [markdown]
# ### Task P2_07 : Snooker (2 Star)
# ![P2_07 Snooker_01.png](attachment:9de59c62-49a7-46b5-b4fa-1c2ec885be77.png)
#
# ![P2_07 Snooker_02.png](attachment:68e55d30-8cf4-45d9-bfff-9044bf25b12f.png)

# %% [markdown]
# ### Task P2_08 : Thai Numerals (2.5 Star)
# ![P2_08 Thai Numerals_01.png](attachment:c18a0328-7afc-436e-9da4-54ab20fa0e64.png)
#
# ![P2_08 Thai Numeral_02.png](attachment:7d17e67a-cfad-4184-a9ae-1e684dc62920.png)

# %%
def to_Thai(N) :
    out = ''
    
    # 1 : check digit_10**3 first
    if N >= 1000 : # thousands
        digit_pun = ['soon','neung','song','sam','si','ha','hok','chet','paet','kao']
        out += digit_pun[N//1000] + ' ' + 'pun' + ' '
        N %= 1000 # mod 1000 for check 100s
    
    # 2 : check digit_10**2 
    if N >= 100 :
        digit_roi = ['soon','neung','song','sam','si','ha','hok','chet','paet','kao']
        out += digit_roi[N//100] + ' ' + 'roi' + ' '
        N %= 100 # mod 100 for check 10s
        
    # 3 : check digit_10**1 (case sensitive)
    if N >= 10 :
        digit_sib = ['yi','sam','si','ha','hok','chet','paet','kao'] # in 10**1 digit -> we dont have soon and neung
        # check if N >= 20
        if (N//10) >= 2 : 
            out += digit_sib[N//10 - 2] + ' ' + 'sip' + ' '
        else :
            out += 'sip' + ' '
        N %= 10 # mod 10 for check last digit
    
    # 4 : N < 10 for sure (case sensitive)
    digit_nuay = ['soon','et','song','sam','si','ha','hok','chet','paet','kao']
    out += digit_nuay[(N % 10)]
    
    # 5 : if N == 1 (not by modded) but real value is 1 -> change et to neung
    if out == 'et' :
        out = 'neung'
    
    # 6 : if number is 10's multipliers -> change last word to no string !!dont forget to strip spacebar!!
    if out != 'soon' and len(out) > 4 :
        return out.replace('soon' , '').strip() # strip for spacebar
    
    # 7 : result -> return last result !!dont forget to strip spacebar!!
    return out.strip()

# 8 : execute fn
exec(input().strip())

# %% [markdown]
# ### Task P2_09 : Vitamin (3 Star)
# ![P2_09 Vitamin_01.png](attachment:6187102d-7404-439a-b87d-b29613817c3f.png)
#
# ![P2_09 Vitamin_02.png](attachment:b3f63113-2947-4d54-9b2b-78aa64fec20c.png)
