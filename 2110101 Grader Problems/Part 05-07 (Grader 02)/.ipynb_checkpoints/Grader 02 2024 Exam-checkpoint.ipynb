# %% [markdown]
# # 2110101 Grader Problems
# ## Solution by : Nine #1 General (Gr.E)
# ## 2024 Semester 01 : Grader 02 All Problems

# %% [markdown]
# ## Overview
#
# #### Quiz 2 (Computer & Survey Engineering)
# - 2024_T1_Q2_G2_01 : List Rearrangement (2 Star) ☑️
# - 2024_T1_Q2_G2_02 : Text Search (2.5 Star) ☑️
#
# #### Quiz 2 (Survey & Withdrawl Engineering)
# Note : **Survey & Withdrawl** B2 similar to 2023_T2_G2_01 Rude Words **WIthdrawl** B2 same as Survey
# - 2024_T1_Q2_G2_01_SV : Mean of Median of K (2 Star)
# - 2024_T1_Q2_G2_02_SV : Less Offensive Words (2 Star)
#
# #### Quiz 3 (Computer & General Engineering)
# - 2024_T1_Q3_G2_01 : Generations (2 Star) ☑️
# - 2024_T1_Q3_G2_02 : Text Replace (1.5 Star) ☑️
#
# #### Quiz 3 (Survey Engineering)
# Note : **Withdrawl** Don't Have Grader 02 Retake
# - 2024_T1_Q3_G2_01_SV : Downsampling (1.5 Star) ☑️
# - 2024_T1_Q3_G2_02_SV : Sorted Cards (2 Star)
#
# #### Quiz 4 (Survey Engineering)
# - 2024_T1_Q4_G2_01_SV : T-Score TCAS67 (1.5 Star) ☑️
#
# #### Quiz 2 (ISE Exam)
# - 2024_T1_ISE_G2_01 : Find Max Sum of N from Rotated List (1 Star)
# - 2024_T1_ISE_G2_02 : Boxing Match Simulation (2 Star)
# - 2024_T1_ISE_G2_03 : Sentiment Score (2 Star)
# - 2024_T1_ISE_G2_04 : Combining Store Points (1 Star)
#
# #### Quiz 3 (ISE Exam)
# - 2024_T1_ISE_G3_01 :
# - 2024_T1_ISE_G3_02 :
# - 2024_T1_ISE_G3_03 :
# - 2024_T1_ISE_G3_04 :
