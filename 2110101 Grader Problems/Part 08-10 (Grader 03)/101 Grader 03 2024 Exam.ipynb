# %% [markdown]
# # 2110101 Grader Problems
# ## Solution by : Nine #1 General (Gr.E)
# ## 2024 Semester 01 : Grader 03 All Problems

# %% [markdown]
# ## Overview
#
# #### Quiz 3 (Computer & General Engineering)
# - 2024_T1_Q3_G3_01 : Electoral Votes (2.5 Star)
# - 2024_T1_Q3_G3_02 : The Python (3 Star)
#
# #### Quiz 3 (Survey & Withdrawl Engineering)
# - 2024_T1_Q3_G3_01 : Money Change (2 Star)
# - 2024_T1_Q3_G3_02 : Class Registeration (2 Star)
