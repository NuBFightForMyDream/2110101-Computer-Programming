# %% [markdown]
# # 2110101 Grader Problems
# ## Solution by : Nine #1 General (Gr.E)
# ## 2024 Grader #1 Quiz 1 + Quiz 2 Exam (Survey Section Included)

# %% [markdown]
# ## Overview
# ### Normal Problems
#
# #### Quiz 1 (Computer & General Engineering)
# - 2024_T1_G1_Q1_01 : Flowchart Quiz1 2024 (1.5 Star)
# - 2024_T1_G1_Q1_02 : Compound Interest (1.5 Star)
# - 2024_T1_G1_Q1_03 : Rotation 90 and Rotation 180 (2 Star)
#
# #### Quiz 1 (Survey & Withdrawl Engineering)
# Note : **Survey** A1 & A3 Same As General , **Withdrawl** A1 Same as General
# - 2024_T1_G1_Q1_02 : GPAX Calculation (1 Star)
# - 2024_T1_G1_WD_Q1_02 : Cosine Taylor Approximation (1.5 Star)
# - 2024_T1_G1_WD_Q1_03 : Sequence With Ellipsis (1.5 Star)
#
# #### Quiz 2 (Computer & General Engineering)
# Note : **Survey** A1 & A3 Same As General , **Withdrawl** Don't have Q2 in Grader 1
# - 2024_T1_G1_Q2_01 : Flowchart Quiz2 2024 (1 Star)
# - 2024_T1_G1_Q2_02 : Positive Number : Continued Fraction (1 Star)
# - 2024_T1_G1_Q2_03 : Horizontal-Vertical Flip (1 Star)
# - 2024_T1_G1_SV_Q2_02 : Installment (1 Star)
#
# #### Quiz 1 (ISE ICE Exam)
# - 2024_T1_ISE_G1_01 : Expression : Projectile Motion (1 Star)
# - 2024_T1_ISE_G1_02 : String (1 Star)
# - 2024_T1_ISE_G1_03 : Math Flowchart (2.5 Star)
# - 2024_T1_ISE_G1_04 : Major Element (1.5 Star)
# - 2024_T1_ISE_G1_05 : Library System (2.5 Star)

# %% [markdown]
# ### Task 2024_T1_G1_Q1_01 : Flowchart Quiz 1 2024 (1.5 Star)
# ![2024_T1_Q1_G1_01 Flowchart 2567.png](attachment:7e9e9f32-ea39-4e92-bf96-43c2a125fa7f.png)

# %% [markdown]
# ### Task 2024_T1_G1_Q1_02 : Compound Interest (1.5 Star)
# ![2024_T1_Q1_G1_02 Compound Interest.png](attachment:aafd4ff3-52bf-4694-a226-156c80de4e8f.png)

# %% [markdown]
# ### Task 2024_T1_G1_Q1_03 : Rotation 90 and 180 (2 Star)
# ![2024_T1_G1_03 Rot 90 and Rot 180.png](attachment:20a70aa5-285a-42ff-9bc9-0f20cfe99c52.png)

# %% [markdown]
# ### Task 2024_T1_G1_Q1_02_SV : GPAX Calculation (1 Star)
# ![2024_T1_Q1_G1_02 GPAX Calculation.png](attachment:47edec8b-bd3b-4cd9-bb7e-577282a96adf.png)

# %% [markdown]
# ### Task 2024_T1_G1_WD_Q1_02 : Cosine Taylor Approximation (1.5 Star)
# ![2024_T1_Q1_G1_02_WD Cosine Taylor Approximation.png](attachment:8bda721d-b36e-4788-8d09-4410c6a37e66.png)

# %% [markdown]
# ### Tassk 2024_T1_G1_WD_Q1_03 : Sequence With Ellipsis (1.5 Star)
# ![2024_T1_Q1_G1_03_WD Sequence With Ellipsis.png](attachment:15eb7580-5b31-4590-9bcd-1f1551fdb9de.png)

# %% [markdown]
# ### Task 2024_T1_G1_Q2_01 : Flowchart Quiz 2 2024 (1 Star)
# ![2024_T1_Q2_G1_01 Flowchart.png](attachment:633a4ab3-5217-40a2-85ad-667e80d7ed3b.png)

# %% [markdown]
# ### Task 2024_T1_G1_Q2_02 : Positive Number : Continued Fraction (1 Star)
# ![2024_T1_Q2_G1_02 Continued Fraction.png](attachment:51ab88f5-d4eb-45c3-b2b9-a7b8d560b66e.png)

# %% [markdown]
# ### Task 2024_T1_G1_Q2_03 : Horizontal-Vertical Flip (1 Star)
# ![2024_T1_Q2_G1_03 Horizontal & Vertical Flip.png](attachment:4944c045-001c-4ef8-81f5-0d1368ecde70.png)

# %% [markdown]
# ### Task 2024_T1_G1_Q2_02_SV : Installment (1 Star)
# ![2024_T1_Q2_G1_02_SV Installment.png](attachment:20b22e88-3c59-427e-a5ec-8902c67faf6b.png)

# %% [markdown]
# ### Task 2024_T1_ISE_G1_01 : Expression : Projectile Motion (1 Star)
# ![2024_T1_ISE_G1_01 Expression 01.png](attachment:53c6c6b3-8f6e-435b-b060-d54702a3feda.png)
#
# ![2024_T1_ISE_G1_01 Expression 02.png](attachment:d514bb81-fed6-4bce-a6a0-23bb2e9ba3c4.png)

# %% [markdown]
# ### Task 2024_T1_ISE_G1_02 : String (1 Star)
# ![2024_T1_ISE_G1_02 String.png](attachment:05263843-b70b-48a9-8488-a781e056bc0b.png)

# %% [markdown]
# ### Task 2024_T1_ISE_G1_03 : Math Flowchart (2.5 Star)
# ![2024_T1_ISE_G1_03 Math Flowchart 01.png](attachment:c0f78873-3c7f-4011-a8c7-42c1080e3999.png)
#
# ![2024_T1_ISE_G1_03 Math Flowchart 02.png](attachment:4b0c7589-2f59-4d28-8ca1-86198a377700.png)

# %% [markdown]
# ### Task 2024_T1_ISE_G1_04 : Major Element (1 Star)
# ![2024_T1_ISE_G1_04 Major Element.png](attachment:e4c9caf4-8e2a-4491-a336-0a027ca11523.png)

# %% [markdown]
# ### Task 2024_T1_ISE_G1_05 : Library System (2.5 Star)
# ![2024_T1_ISE_G1_05 Lbrary System 01.png](attachment:0a33ad3b-13b9-4fea-8f02-9787d597817f.png)
#
# ![2024_T1_ISE_G1_05 Library System 02.png](attachment:53c393b4-b0f9-4fb3-8da3-16169ccc9ecb.png)
