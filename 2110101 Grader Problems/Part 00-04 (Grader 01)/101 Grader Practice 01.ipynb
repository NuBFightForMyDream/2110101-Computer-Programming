# %% [markdown]
# # 2110101 Grader Problems
# ## Solution by : Nine #1 General (Gr.E)
# ## Grader Practices For Exam #01 (Basic Problems)

# %% [markdown]
# ## Overview
# ### Flowchart
# - P1_01 : Flowchart #01 (2 Star) ☑️
# - P1_02 : Flowchart #02 (3 Star) ☑️
# - P1_03 : Flowchart #03 (3 Star) ☑️
# - P1_04 : Flowchart #04 (3 Star) ☑️
# - P1_05 : Flowchart #05 (3 Star) ☑️
# ### Normal Problems
# - P1_06 : Older (1.5 Star) ☑️
# - P1_07 : Run Length Encoding (RLE) (2 Star) ☑️
# - P1_08 : Rock Paper Scissors (2 Star) ☑️
# - P1_09 : Bowling (3 Star)
# - P1_10 : Golf (2 Star) ☑️
# - P1_11 : Rotate String (3 Star) ☑️

# %% [markdown]
# ### Task P1_01 : Flowchart #01 (2 Star)

# %% [markdown]
# ![Screenshot 2024-09-10 215621.png](attachment:482ecbbb-e3c0-4a71-9c11-9df418322288.png)

# %%
# 1 : รับ input เเบบ list comprehension -> list (of int)
x1,x2,x3,x4,x5 = [int(e) for e in input().split()]

# 2 : สร้าง condition ตาม flowchart (ค่อยๆไล่ทีละส่วน)

# ฝั่ง Left
if x1-x5 > x2 :
    if x2 > x3 + x1 :
        if x3+x5 > x4 :
            print('C5')
        else :
            if x3 < x5 :
                print('C6')
            else :
                print('C7')
            print('C8') # บังคับ print
    else :
        pass    
        
# ฝั่ง Right
else :
    if x2-x1 > x3 : 
        pass
    else :
        if x4 < x5+x1 :
            if x3+x2 > x5 :
                print('C3')
            else :
                print('C2')         
            print('C4') # บังคับ print
        else :
            print('C1')
# Out:
# C2
# C4

# %% [markdown]
# ### Task P1_02 : Flowchart #02 (3 Star)
# ![Screenshot 2024-09-10 214401.png](attachment:80e22772-9e0d-483b-92a7-65111f06fe98.png)
#
# ![Screenshot 2024-09-10 214410.png](attachment:6d642216-a71b-4f49-a6e1-e4616c071b4e.png)

# %%
# 1 : รับ input n,k (int) -> โจทย์ไม่บอก เเต่รู้เองว่ารับเเบบ list comprehension
n,k = [int(e) for e in input().split()]

# 2 : check condition ใหญ่ก่อน
if n % 2 != 0 :
    sum_a = 0 ; sum_b = 0 ; sum_c = 0 ; m = 0
    
    # วน while loop
    while m < k :
        a,b,c = [int(e) for e in input().split()]
    
        if a == b :
            if (a == b == c) :
                if (a + b) > k : # รอบคอบขึ้นหน่อย ระวังผิดngo x-x
                    sum_a += 1
                    sum_b += 2
                    sum_c -= 3
                else :           # รอบคอบขึ้นหน่อย ระวังผิดngo x-x
                    sum_a -= 3
                    sum_b -= 2
                    sum_c += 1
            else :
                sum_a += 2
                sum_b -= 3
        
        m += 1 # +1 ทุก loop
    
    # ออกจาก loop -> บังคับ print sum_a , sum_b , sum_c
    print(sum_a , sum_b , sum_c)
    
elif n % 2 == 0 :
    s,t = [int(e) for e in input().split()]
    
    x = s ; y = t
    
    if s > t :
        x = s - t
    
    else :
        if s < t : #เขียนย่อเป็น elif ก็ได้
            y = 2 * (t - s)
     
    # บังคับเช็ค if       
    if x+y > k :
        x,y = y,x
        x = y + s**2
    
    # บังคับ print x,y    
    print(x,y)
# Out:
# 3 -11 1

# %% [markdown]
# ### Task P1_03 : Flowchart #03 (3 Star)
# ![Screenshot 2024-09-10 214638.png](attachment:ae44fae4-f147-497c-9fb3-83a962b48bb5.png)

# %%
# 1 : รับ input + import math
x = input('Enter A,B,C,D : ').split() #List of str
a,b,c,d = int(x[0]) , int(x[1]) , int(x[2]) , int(x[3]) #int
import math

# 2 : check cd ใหญ่
if a == 1 :
    # ฝั่งซ้าย
    c,d = d,c
    if b == 1 :
        c = c + d
    elif b == 2 :
        c = c - d
    elif b != 3 :
        c = c + c**d
    else :
        c = c / d
    
    # จบที่สมการล่างสุด
    ses = d + math.sqrt((c/b)**3 + d)
    suan = 2 + b*d
    a = ses / suan
    
elif a != 1 :
    # ฝั่งขวา
    if a == 2 : # block 2
        if b > 1 :
            c = c + d
        if b > 2 : # บังคับcheck if ไม่ว่าY/N
            c = c / d
        if b > 3 : # บังคับcheck if ไม่ว่าY/N
            c = c + c**d
        elif b <= 3 : #else ก็ได้
            a = math.log(c,10)
        
    else : #block 3
        while a > d :
            a = a - 2
            if a < b :
                break # ถ้า Y -> break
            else :
                c = c + a

# จบ loop -> print a,b,c,d
print(a,b,c,d)

# %% [markdown]
# ### Task P1_04 : Flowchart #04 (3 Star)
# ![Screenshot 2024-09-10 214655.png](attachment:440b94a5-223d-4309-84e3-73c4cce862dd.png)
#
# ![Screenshot 2024-09-10 214707.png](attachment:ccc6ff34-0bd3-4422-939b-b6a0c419130b.png)

# %%
# 1 : รับ input + check cd 
x1 = str(input()).strip() #str
x2 = str(input()).strip() #str
x3 = str(input()).strip() #str

x = x1 + x2 + x3 #str

if len(x) == 9 :
    win = '-' ; i = 0 # int
    
    # เริ่ม check
    
    while i < 3 : # block ซ้าย
        
        if x[3*i] == x[3*i + 1] == x[3*i + 2] : #string cp.
            win = x[3*i]
            break # ดูลูกศรดีๆ อย่าลืม break (ออก loop เเล้ว)
        
        elif x[i] == x[i+3] == x[i+6] :
            win = x[i]
            break # ดูลูกศรดีๆ อย่าลืม break (ออก loop เเล้ว)
            
        i += 1
    
    # block ขวา
    
    # จบ while loop เเล้ว
    if win == '-' :
    
        if x[0] == x[4] == x[8] :
            win = x[0]
        
        if x[3] == x[4] == x[6] : # ไม่ว่า Y/N -> บังคับ check if
            win = x[6]
    
    # จบ block ขวาบน
    
    if win == '-' :
        print('???')
        
    else :
        print(win)
    

elif len(x) != 9 :
    print('ERROR')

# %% [markdown]
# ### Task P1_05 : Flowchart #05 (3 Star)
# ![Screenshot 2024-09-10 214729.png](attachment:595ed8e5-6ce6-4bf9-bb99-f26f37337574.png)
#
# ![Screenshot 2024-09-10 214738.png](attachment:11af048f-bf81-4452-9eff-66eb92fe338d.png)

# %%
# 1 : รับ str c
c = str(input('Enter Alphabet A-Z : ')) #str
import math

# 1.2 : check cd ใหญ่
if c == 'S' :
    # ฝั่งขวา
    m = int(input('Enter M : '))
    
    q = 1 ; r = 0 ; t = 1 ; k = 1; n = 3; x = 3; i = 0; p = "" # define ตป.
    
    while i < m :
    
        if (4*q + r - t) < (n*t) :
        
            p = p + str(n)
            i = i + 1
            a = 10 * (r - n*t)
            n = (10 * (3*q + r)) // t - (10*n)
            q = 10 * q
            r = a
        
        else :
            a = (2*q + r) * x
            b = (7*q*k + 2 + x*r) // (x*t)
            q = k * q
            t = x * t
            x = x + 2
            k = k + 1
            n = b
            r = a  
        
    #  ออก loop เเล้ว
    p = p[0] + '.' + p[1::1] # ตัวซ้ายสุด = p[0] , ทุกตัวยกเว้นซ้ายสุด = p[1::1] (ไม่ได้เอาค่าถอยหลัง อย่าเมา!!)
    print('pi =' , p)
    
else :
    
    if c == 'R' :
        
        # รับ input n
        n = int(input('Enter N : ')) #int
        sum = 0
        
        # for loop -> เพื่อหา sum
        for k in range(0 , n+1) : # เริ่ม loop ตต.0 ถึง n (ไม่เอา n+1)
            p = ((-3)**(-k)) / (2*k + 1)
            sum += p
        p = math.sqrt(12) * sum # ใส่ √12 ด้านหน้าค่า
        p = round(p,12) # ปัดเศษ 12 ตน.
        
        print('pi =' , p) # อย่าลืม print
        
    else :
            
        if c == 'P' :
            p = math.sqrt(7 + math.sqrt(6+math.sqrt(5)) )  
            p = round(p,6)
            print('pi =' , p)
        else :
            print('Invalid')
# Out:
# pi = 3.1415

# %% [markdown]
# ### Task P1_06 : Older (1.5 Star)
# ![P1_06 Older.png](attachment:ed645e48-e33a-4dd0-a438-2f1be790fc1b.png)

# %%
# 1 : str -> split เป็น list
info1 = input('Enter Info 1 : ').split()
#list of str -> ['nick' , 'monthname' , 'd,' ,'yyyy']

info2 = input('Enter Info 2 : ').split()
#list of str -> ['nick' , 'monthname' , 'd,' ,'yyyy']

# 1.2 : ตัดปลายออกด้วย ,
date1 = int(info1[2].strip(',')) # 'd' -> d
date2 = int(info2[2].strip(',')) # 'd' -> d

# 2 : สร้าง list ชื่อเดือน เเล้ว index (ไม่ก็สร้าง ตป.เเทนเลขเดือน เเล้วเทียบ)
list_month = ['Null','January','February','March','April','May','June','July','August','September','October','November','December']

# 3 : สร้าง ตป.ที่จำเป้นต้องใช้จากการ index ก่อน

    # 3.1 : year
age1 = 2567 - int(info1[3]) #int - int(str) = int
age2 = 2567 - int(info2[3]) #int - int(str) = int

    # 3.2 : month (โกง ใช้ index เเม่ม)
month1 = list_month.index(info1[1]) #int
month2 = list_month.index(info2[1]) #int

    # 3.3 : date (ทำข้างบนเเล้ว)
    
# 4 : เทียบ cd (Logic คล้ายๆข้อย้ายภาค)

if age1 == age2 :
    # age เท่า -> check month     
    if month1 == month2 :
        # month เท่า -> check date
        if date1 == date2 : # print 1 , 2
            print(info1[0] , info2[0]) #nick1 nick2
            
        elif date1 > date2 : # print 2 (2 older)
            print(info2[0]) #nick2
        
        elif date1 < date2 : # print 1 (1 older)
            print(info1[0]) #nick1
        
    elif month1 > month2 : # print 2 (2 older)
        print(info2[0]) #nick2
        
    elif month1 < month2 : # print 1 (1 older)
        print(info1[0]) #nick1
    
elif age1 < age2 : # print 2
    print(info2[0]) # nick2
    
elif age1 > age2 : # print 1
    print(info1[0]) # nick1
# Out:
# Noey

# %% [markdown]
# ### Task P1_07 : RLE to String (2 Star)
# ![P1_07 RLE2STR.png](attachment:38b9ed5c-4607-41be-b92d-575274d52091.png)

# %%
# 1 : รับ input เพื่อเเยกเคส
algo = str(input('Enter str2RLE or RLE2str : '))

# 2 : case 1 : str -> RLE
if algo == 'str2RLE' :
    # ใช้ Logic จากข้อ 04_08 RLE :
    
    # 2.1 : รับ input rle + สร้าง output str ว่าง (เดี๋ยวค่อยๆเพิ่ม str)
    rle1 = str(input('Enter RLEs : '))
    rle1_output = ''
    
    # 2.2 : ตั้งตป.ที่จำเป็น
    count1 = 1 ; check1 = rle1[0] # เจอตัวเเรก นับเป็น 1 , rle ให้เป็น str ตัวเเรก
    
    # 2.3 : for loop -> check cd.
    for i in range(1 , len(rle1)) : # เริ่ม check index 1 ถึงสุดท้าย
        if check1 == rle1[i] :
            count1 += 1
    
        elif check1 != rle1[i] :
        # เพิ่มค่าเดิมก่อน
            rle1_output += ( str(check1) + ' ' + str(count1) + ' ' ) # Ex : A 5 Y 3 
        # เปลี่ยนค่า count , check
            count1 = 1 # เจอตัวใหม่ นับเป็น 1
            check1 = rle1[i] #  เปลี่ยนให้เป็นตัวที่ i 
        
    # 2.4 : เพิ่มค่าสุดท้าย เเล้ว print rle_output
    rle1_output += ( str(check1) + ' ' + str(count1) + ' ' ) 
    print(rle1_output)
    
# 3 : RLE -> str
elif algo == 'RLE2str' :
    
    # 3.1 : split str ทั้งหมดก่อน +  สร้าง str ว่าง
    rle2 = input('Enter RLEs : ').split() # list of str
    str2_output = '' 
        
    # 3.2 : for loop อีกรอบ เพื่อจะทำการเพิ่มstr
    for j in range(0 , len(rle2) - 1 , 2) :
        str2_output += ( rle2[j] * int(rle2[j+1]) ) 
        # rle2[j] = ALphabet , rle2[j+1] = Number
        
    # 3.3 : print output
    print(str2_output)
    
# 4 : case อื่น
else :
    print('Error')
# Out:
# T 2 Y 2 U 2

# %% [markdown]
# ### Task P1_08 : Rock Scissors Paper (2 Star)
# ![P1_08 RSP(025).png](attachment:a2d88bbd-775b-4cfd-b0f1-045cc039aff5.png)

# %%
# 1 : รับ input จน.เกมที่จะเล่น m (int)
m = int(input('Enter Round : '))

# 2 : สร้าง ตป.ที่จำเป็นต้องใช้
round = 0  
end = 3*m # 3 x จน.รอบ (ตามเงื่อนไขโจทย์X
tie = True # กำหนดว่าเสมอมั้ย (กำหนด default = True)
count_1 = 0; count_2 = 0

# 3 : while loop -> ตราบใดที่ยังไม่เกิน 3m รอบ เล่นต่อ
while round < end :
    # 3.1 : รับ input -> split เป็น list of str
    algo = input('ENter R/S/P by P1 P2 : ').split() # list of str
    
    # 3.2 : check เงื่อนไขที่ทำให้เเต่ละคนชนะ -> 6 cases (ตนละ 2 , 3 tools)
    if algo[0] == 'P' and algo[1] == 'R' :
        count_1 += 1
        
    elif algo[0] == 'P' and algo[1] == 'S' :
        count_2 += 1
        
    elif algo[0] == 'S' and algo[1] == 'P' :
        count_1 += 1
        
    elif algo[0] == 'S' and algo[1] == 'R' :
        count_2 += 1
        
    elif algo[0] == 'R' and algo[1] == 'P' :
        count_2 += 1
        
    elif algo[0] == 'R' and algo[1] == 'S' :
        count_1 += 1
    
    # 3.3 : เพิ่ม จน. round เมื่อเล่นเสร็จ
    round += 1
    
    # 3.4 : check cd -> ถ้า จน.ชนะ (count) = จน.รอบ (m) -> ให้คนนั้นชนะเลย + ออก loop
    if (count_1 == m):
        tie = False
        print(count_1 , count_2)
        print('Player 1 wins')
        break # ออกได้เลย ถ้าชนะ
    
    elif (count_2 == m) :
        tie = False
        print(count_1 , count_2)
        print('Player 2 wins')
        break # ออกได้เลย ถ้าชนะ
    
# 4 : จบ loop เเล้ว -> check ว่าเพราะอะไร (จบก่อน or Tie)
if tie : # ถ้า Tie -> print Tie & คะเเนน
    print(count_1 , count_2)
    print('Tie')
# Out:
# 0 0
# Tie

# %% [markdown]
# ### Task P1_09 : Bowling (3 Star)
# ![P1_09_01 Bowling.png](attachment:9929f1a4-bfbe-4107-b684-57963f281701.png)
#
# ![P1_09_02 Bowling.png](attachment:d81eaae7-fee6-4cdf-885f-d7ec06399b20.png)

# %%
# 1 : รับ result จากการเล่น bowling จริง
result = input('Enter Bowling Result : ').strip()

# 2 : รับ target -> check ว่าป้อนเลขใดเข้ามา (1-9 => เเสดงคะเเนนรวม , เลขอื่น => เเสดงค่าเฟรมที่กรอกเข้ามา)
target = int(input())

# 3 : กำหนดตัวเเปร i , total_score
i = 0               # เก็บ index เริ่มต้นของเฟรม
total_score = 0     # เก็บคะเเนนรวม

# 4 : for loop วน จน.เฟรม ให้ครบ 10 เฟรม
for frame in range(1,11) :
    
    # 4.1 : (To Do) เขียน case เเยกการเกิดคะเเนนได้ 7 วิธี
    
    # Case 1 : X -> X -> X == 10 + 10 + 10 = 30
    if result[i : i+3] == 'XXX' :
        total_score += 30
        i += 3
        pass
    
    # Case 2 : X -> X -> ? == 10 + 10 + ? = (20,30)    
    elif result[i : i+2] == 'XX' :
        total_score += (20 + int(result[i+2]) ) # คิดคะเเนนตัวสุดท้าย เเปลง str เป็น int
        i += 3
        pass
        
    # Case 3 : X -> ? -> / == 10 + ?/ -> splash เป้น 20
    elif result[i] == 'X' and result[i+2] == '/' :
        total_score += 20
        i += 3
        pass
    
    # Case 4 : X -> ? -> ? == 10 + ?1 + ?2 = (10,20)
    elif result[i] == 'X' :
        total_score += ( 10 + int(result[i+1]) + int(result[i+2]) ) # คิดคะเเนน 2 ตัวสุดท้าย เเปลง str เป็น int
        i += 3
        pass
    
    # Case 5 : ? -> / -> X == splash 10 + X = 20
    elif result[i+1 : i+3] == '/X' :
        total_score += 20 
        i += 3
        pass
    # Case 6 : ? -> / -> ? == 10 + ? = (10,20)
    elif result[i+1] == '/' :
        total_score += ( 10 + int(result[i+2])) # คิดคะเเนนตัวสุดท้าย เเปลง str เป็น int
        i += 3
        pass
    
    # Case 7 : ? -> ? (ได้เเค่ 2 ครั้ง)
    else :
        total_score += (int(result[i]) + int(result[i+1]) + int(result[i+2]) )
        i += 2
        pass
    
print(total_score)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 5
#       2 result = input('Enter Bowling Result : ').strip()
#       4 # 2 : รับ target -> check ว่าป้อนเลขใดเข้ามา (1-9 => เเสดงคะเเนนรวม , เลขอื่น => เเสดงค่าเฟรมที่กรอกเข้ามา)
# ----> 5 target = int(input())
#       7 # 3 : กำหนดตัวเเปร i , total_score
#       8 i = 0               # เก็บ index เริ่มต้นของเฟรม
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# ### Task P1_10 : Golf (2 Star)
# ![P1_10_01 Golf.png](attachment:222666da-62c9-4427-9098-0134cd833be9.png)
#
# ![P1_10_02 Golf.png](attachment:1bdc675c-c77c-4150-9d18-d45f8d1dd9ae.png)

# %%
# 1 : สร้าง list ว่าง -> เพื่อเพิ่มค่าเข้าไปเรื่อยๆ ใน list
import math
par = [];  stroke = [];  choose = [];  repair = []

# 2 : for loop 9 รอบ : เพื่อรับ input & เพิ่มสมาชิก
for i in range(9) :
    info = input('Enter Par / Stroke / Choose : ')
    # 2.1 : split  เเล้วเเปลงสมาชิกเป็น intT
    p = int(info.split()[0]); s = int(info.split()[1]) ; ch = int(info.split()[2])
    
    # 2.2 : เพิ่มค่าเข้าไปเรื่อยๆ ใน list ว่าง
    par += [p];  stroke += [s];  choose += [ch] # Note : การนำ list + list = การนำสมาชิกใน list มาต่อกัน
    
    # ตอนนี้มีlist par , stroke , change , repair เเล้ว => list (of int)
    
    # 2.3 : check cd -> ถ้าป้อน 1 ให้ปรับปรุง stroke , ถ้าป้อน 0 ไม่ต้องทำอะไร
    if choose[i] == 1 :
        # stroke ปรับปรุง => เอา min ของค่า stroke ตัวนั้นๆ กับ ค่า par ตัวนั้นๆ +2
        change = min( stroke[i] , par[i] + 2 )
        repair += [change] # เพิ่มสมาชิกใน list

# 3 : ตอนนี้มี list ของทั้งหมดเเล้ว -> หา sum เเล้วเเทนเข้าสูตรหาเเต้มต่อ (extra)
par = sum(par);     stroke = sum(stroke);   repair = sum(repair);    # หาค่า sum เเล้วเเทนลง ตป.เดิม
    
extra = math.floor( 0.8 * (1.5 * repair - par) ) # เกิดปัญหาว่า ถ้าใช้ int มันจะปัดขึ้น (in case จน.ลบ) => เเก้โดยลองใช้ floor fn (ไม่เเนะนำ) หรืออาจจะต้องกำหนด condition ในการใช้
total = stroke - extra # int

# 4 : print stroke , extra , total คนละบรรทัด
print(stroke);  print(extra);   print(total)
# Out:
# 35
# 0
# 35

# %% [markdown]
# ### Task P1_11 : Rotate String (3 Star)
# ![P1_11 Rotate String.png](attachment:8c76428b-009b-4442-acd8-bd8c5abb33f7.png)

# %%
## Sol 1 : Using String 80 %

# 1 : input degree & algo
algo_degree = input()
line = int(input())
str_all = ''
length = 0
invalid = False; check_len = []

# 2 : add all str to str_all
for i in range(line) :
    inp = input().strip()
    str_all += inp
    char = len(inp); check_len += [char]
    
# check len first
for j in range(len(check_len) - 1) :
    if (check_len[j] != check_len[j+1]) and (line > 1) :
        invalid = True
        break
    
if invalid == True :
    print('Invalid size')
# 3 : check each algorithm
    # 3.1 : rot 90
elif algo_degree == '90' :
    str_rot90 = ''
    for i in range(char) :
        str_rot90 = str_all[-(char - i) : : - char]
        print(str_rot90)
    
    ## len_all = 12 , 3 line , 4 char
    ## we need 3 char , 4 line
    ## str_rot = [-4::-4] + [-3::-4] + [-2::-4] + [-1::--4]
    # for loop 4 times -> 0 to len
    # -(len - i) => -4 , -3 , -2 , -1 (- len step) Ex step = -4

# 2 : add all str to str_all
elif algo_degree == '180' :
    str_180 = str_all[::-1]
    for i in range(line) :
        part = int(len(str_all) / line)
        str_rot180 = str_180[part*i : part*(i+1)]
        print(str_rot180)
        
elif algo_degree == 'flip' :
    str_all = ' ' + str_all
    for i in range(line) :
        str_flip = str_all[char*(i+1) : char*(i) : -1]
        print(str_flip)
# Out:
# 4321
# DCBA

# %%
## Sol2 : Using List
# 1 : input
algo = input('Enter Algorithm : ')
line = int(input('Enter Line : '))
list_str = []; check_size = []

# 2 : add all str to str_all
for i in range(line) :
    ip = input('Enter String : ')
    list_str += [ip] # str
    check_size += [len(ip)]
    
## 3 : check size first
invalid = False
for i in range(len(check_size) - 1) :
    if check_size[i] != check_size[i+1] :
        invalid = True
        break

# 4 : check each condition
if invalid == True : 
    print('Invalid size')
    
# 4.1 : rot90 -> sum all str -> choose reverse -> print
elif algo == '90' :
    # Ex : Choose 8 4 0 , 9 4 1 , 10 5 2 , 11 6 3
    
    # 4.1.1 : for loop -> sum str
    str_sum = ''
    for i in range(len(list_str)) : 
        str_sum += list_str[i] # str + str
        
    # 4.1.2 : cut string -> for loop
    # case 1 : 8 4 0 , 9 5 1 , 10 6 2 , 11 7 3 (have pb. with 4 char -> starts with D)
    # case 2 : minus id. is safer -> -4 -8 -12 , -3 -7 -11 , -2 -6 -10 , -1 -5 -9
    
    for i in range(len(ip)) : 
        str_rot90 = str_sum[-(len(ip) - i) : : - len(ip)] # read case 2
        print(str_rot90)
                
# 4.2 : rot180 -> reverse pos. -> reverse char in each pos. 
elif algo == '180' :
    
    # 4.2.1 : reverse position
    list_str = list_str[::-1]
    
    # 4.2.2 : reverse char in each position (for loop)
    for i in range(len(list_str)) :
        list_str[i] = (list_str[i])[::-1] # reverse char
        
        # Don't Forget to print each position
        print(list_str[i])

# 4.3 : flip -> reverse char in each pos.
elif algo == 'flip' :
    
    # 4.3.1 : for loop -> reverse char in each position
    for i in range(len(list_str)) :
        list_str[i] = (list_str[i])[::-1]
        
        # Don't Forget to print each position
        print(list_str[i])
# Out:
# Invalid size
