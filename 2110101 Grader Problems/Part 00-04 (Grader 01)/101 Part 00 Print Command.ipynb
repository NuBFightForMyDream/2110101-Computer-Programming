# %% [markdown]
# # 2110101 Grader Problems
# ## Solution by : Nine #1 General (Gr.E)
# ## Part 00 : print() command

# %% [markdown]
# ### Overview
# - 00_01 : Hello (1/2 Star) ☑️
# - 00_02 : Big Numbers (1 Star) ☑️
# - 00_03 : Mountain Valley (1 Star) ☑️

# %% [markdown]
# ### Task 00_00 : Hello (1 Star)
# ![Screenshot 2024-08-12 134243.png](attachment:720c9eab-4502-4298-ad55-103c25410b0a.png)

# %%
# Input : -
# Process : -
# Output : คำสั่งตามที่โจทย์บอก

# Logic : -
# Step : print ตามที่โจทย์บอก

print('Hello Python.')
print('We\'re using Python 3.') # เราสามารถพิมพ์ \ ก่อนหน้า ' เพื่อกันระบบสับสน
# มีอีกวิธี พิมพ์ "" เเทนการใช้ ''
# Out:
# Hello Python.
# We're using Python 3.

# %% [markdown]
# ### Task 00_02 : Big Number (1 Star)
# ![Screenshot 2024-08-12 134429.png](attachment:f55bfd9d-d65f-442a-b1cd-c50a4ba97fee.png)

# %%
# Input : -
# Process : -
# Output : คำสั่งตามที่โจทย์บอก

# Logic : -
# Step : print ตามที่โจทย์บอก

# Sol 1 : กำหนดตัวเเปร เเล้ว print
int_1 = 2938402734091273094162387451928736401926340971234 #int
int_2 = 9208209384928743098273495872039847509273497 #int
sum = int_1 + int_2 #int

print(int_1)
print('+')
print(int_2)
print('=')
print(sum)

print('------------------------------------------------')

# Sol 2 : print ตรงๆ ทีละบรรทัด
print('2938402734091273094162387451928736401926340971234') #str
print('+')
print('9208209384928743098273495872039847509273497') #str
print('=')
print(str(2938402734091273094162387451928736401926340971234 + 9208209384928743098273495872039847509273497)) #str
# Out:
# 2938402734091273094162387451928736401926340971234
# +
# 9208209384928743098273495872039847509273497
# =
# 2938411942300658022905485725424608441773850244731
# ------------------------------------------------
# 2938402734091273094162387451928736401926340971234
# +
# 9208209384928743098273495872039847509273497
# =
# 2938411942300658022905485725424608441773850244731

# %% [markdown]
# ### Task 00_03 : Mountain Valley (1 Star)
# ![Screenshot 2024-08-12 134625.png](attachment:d4defb08-78fa-408b-9c37-cd8c71c358a7.png)

# %%
# Input : -
# Process : -
# Output : คำสั่งตามที่โจทย์บอก

# Logic : - (อย่าหาทำ การนั่งนับสัญลักษณ์ ไมช่วยเชี่ยไรเลย)

# Sol 1 : print มันตรงๆเลย (ก็อปโค้ดเหอะ โคตรเยอะ) ===> อย่าลืมว่า เวลา print \ ห้ามพิมพ์ตัวเดียว ระบบสับสน -> ต้องพิมพ์ \\ ระบบ ok
print('+------------------------------------------+') #line 1
print('|................................/\\........|') #line 2
print('|.............................../##\\.......|') #line 3
print('|............................../####\\......|') #line 4
print('|............................./######\\.....|') #line 5
print('|............................/########\\....|') #line 6
print('|.......__................../##########\\...|') #line 7
print('|....../##\\................/############\\..|') #line 8
print('|./\\../####\\......../\\..../##############\\.|') #line 9
print('|/##\\/######\\....../##\\../################\\|') #line 10
print('|############\\..../####\\/##################|') #line 11
print('|#############\\__/#########################|') #line 12
print('+------------------------------------------+') #line 13

## print ออกมาได้ค่า เเต่งงว่าทำไมมันขึ้นว่า syntax error
# Out:
# +------------------------------------------+
# |................................/\........|
# |.............................../##\.......|
# |............................../####\......|
# |............................./######\.....|
# |............................/########\....|
# |.......__................../##########\...|
# |....../##\................/############\..|
# |./\../####\......../\..../##############\.|
# |/##\/######\....../##\../################\|
# |############\..../####\/##################|
# |#############\__/#########################|
# +------------------------------------------+
